# %%
import tensorflow as tf
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dropout,Input,Flatten,Dense,MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator  # Data Augumentation
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
#
# KeyboardInterrupt

# %%
tf.test.is_gpu_available()
# Out:
# False

# %%
batchsize=8

# %%
train_datagen= ImageDataGenerator(rescale=1./255, rotation_range=0.2,shear_range=0.2,
    zoom_range=0.2,width_shift_range=0.2,
    height_shift_range=0.2, validation_split=0.2) #20% of the data goes to validation data and rest goes to the training data 

#to bring all the images in same size in train data.
train_data= train_datagen.flow_from_directory(r'C:\Users\91989\project expo\MINI_PROJECT_2023\mrlEyes_2018_01\Prepared_Data\train',
                                target_size=(80,80),batch_size=batchsize,class_mode='categorical',subset='training' )

validation_data= train_datagen.flow_from_directory(r'C:\Users\91989\project expo\MINI_PROJECT_2023\mrlEyes_2018_01\Prepared_Data\train',
                                target_size=(80,80),batch_size=batchsize,class_mode='categorical', subset='validation')

# %%
test_datagen = ImageDataGenerator(rescale=1./255)

#to bring all the images in same size in test data.
test_data = test_datagen.flow_from_directory(r'C:\Users\91989\project expo\MINI_PROJECT_2023\mrlEyes_2018_01\Prepared_Data\test',
                                target_size=(80,80),batch_size=batchsize,class_mode='categorical')

# %%
bmodel = InceptionV3(include_top=False, weights='imagenet', input_tensor=Input(shape=(80,80,3)))
hmodel = bmodel.output
hmodel = Flatten()(hmodel)
hmodel = Dense(64, activation='relu')(hmodel)
hmodel = Dropout(0.5)(hmodel)
hmodel = Dense(2,activation= 'softmax')(hmodel)

model = Model(inputs=bmodel.input, outputs= hmodel)
for layer in bmodel.layers:
    layer.trainable = False

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_2 (InputLayer)           [(None, 80, 80, 3)]  0           []
#
#  conv2d_94 (Conv2D)             (None, 39, 39, 32)   864         ['input_2[0][0]']
#
#  batch_normalization_94 (BatchN  (None, 39, 39, 32)  96          ['conv2d_94[0][0]']
#  ormalization)
#
#  activation_94 (Activation)     (None, 39, 39, 32)   0           ['batch_normalization_94[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 37, 37, 32)   9216        ['activation_94[0][0]']
#
#  batch_normalization_95 (BatchN  (None, 37, 37, 32)  96          ['conv2d_95[0][0]']
#  ormalization)
#
#  activation_95 (Activation)     (None, 37, 37, 32)   0           ['batch_normalization_95[0][0]']
#
#  conv2d_96 (Conv2D)             (None, 37, 37, 64)   18432       ['activation_95[0][0]']
#
# ...

# %%
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping, ReduceLROnPlateau

# %%
checkpoint = ModelCheckpoint(r'C:\Users\91989\project expo\MINI_PROJECT_2023\mrlEyes_2018_01\model2.h5',
                            monitor='val_loss',save_best_only=True,verbose=3)

earlystop = EarlyStopping(monitor = 'val_loss', patience=20, verbose= 3, restore_best_weights=True)

learning_rate = ReduceLROnPlateau(monitor= 'val_loss', patience=3, verbose= 3, )

callbacks=[checkpoint,earlystop,learning_rate]

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy',metrics=['accuracy'])

model.fit_generator(train_data,steps_per_epoch=train_data.samples//batchsize,
                   validation_data=validation_data,
                   validation_steps=validation_data.samples//batchsize,
                   callbacks=callbacks,
                    epochs=50)
# Out:
# C:\Users\91989\AppData\Local\Temp/ipykernel_12628/567684715.py:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(train_data,steps_per_epoch=train_data.samples//batchsize,
# Epoch 1/50
# 6790/6791 [============================>.] - ETA: 0s - loss: 0.1573 - accuracy: 0.9400
# Epoch 1: val_loss improved from inf to 0.29295, saving model to C:\Users\91989\project expo\MINI_PROJECT_2023\mrlEyes_2018_01\model.h5
# 6791/6791 [==============================] - 528s 63ms/step - loss: 0.1573 - accuracy: 0.9400 - val_loss: 0.2929 - val_accuracy: 0.8886 - lr: 0.0010
# Epoch 2/50
# 6791/6791 [==============================] - ETA: 0s - loss: 0.1558 - accuracy: 0.9402
# Epoch 2: val_loss improved from 0.29295 to 0.27936, saving model to C:\Users\91989\project expo\MINI_PROJECT_2023\mrlEyes_2018_01\model.h5
# ...

# %%
#model evaluation

# %%
acc_tr, loss_tr = model.evaluate_generator(train_data)
print(acc_tr)
print(loss_tr)
# Out:
# C:\Users\91989\AppData\Local\Temp/ipykernel_12628/713691994.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   acc_tr, loss_tr = model.evaluate_generator(train_data)
# 0.12635739147663116
# 0.9523686766624451

# %%
acc_vr, loss_vr = model.evaluate_generator(validation_data)
print(acc_vr)
print(loss_vr)
# Out:
# C:\Users\91989\AppData\Local\Temp/ipykernel_12628/4081756742.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   acc_vr, loss_vr = model.evaluate_generator(validation_data)
# 0.24685242772102356
# 0.8958256840705872

# %%
acc_test, loss_test = model.evaluate_generator(test_data)
print(acc_tr)
print(loss_tr)
# Out:
# C:\Users\91989\AppData\Local\Temp/ipykernel_12628/3655471885.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   acc_test, loss_test = model.evaluate_generator(test_data)
# 0.12635739147663116
# 0.9523686766624451
